# %%
# %tensorflow_version 2.x

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
% cd "/content/gdrive/My Drive/CycleGan-Cats"
# Out:
# /content/gdrive/My Drive/CycleGan-Cats

# %%
% cd CycleGAN-Tensorflow-2/
# Out:
# /content/gdrive/My Drive/CycleGan-Cats/CycleGAN-Tensorflow-2

# %%
% ls datasets/cat2cartoon/trainA| wc -l
% ls datasets/cat2cartoon/trainB| wc -l
# Out:
# 1402
# 971

# %%
! pip install oyaml
! export CUDA_VISIBLE_DEVICES=1
! python train.py --dataset cat2cartoon
# Out:
# Streaming output truncated to the last 5000 lines.
# Inner Epoch Loop:  40% 567/1402 [08:40<11:05,  1.26it/s]
# Inner Epoch Loop:  41% 568/1402 [08:41<11:03,  1.26it/s]
# Inner Epoch Loop:  41% 569/1402 [08:42<11:00,  1.26it/s]
# Inner Epoch Loop:  41% 570/1402 [08:42<11:01,  1.26it/s]
# Inner Epoch Loop:  41% 571/1402 [08:43<11:08,  1.24it/s]
# Inner Epoch Loop:  41% 572/1402 [08:45<13:22,  1.03it/s]
# Inner Epoch Loop:  41% 573/1402 [08:45<12:48,  1.08it/s]
# Inner Epoch Loop:  41% 574/1402 [08:46<12:23,  1.11it/s]
# Inner Epoch Loop:  41% 575/1402 [08:47<12:06,  1.14it/s]
# Inner Epoch Loop:  41% 576/1402 [08:48<11:48,  1.17it/s]
# Inner Epoch Loop:  41% 577/1402 [08:49<11:35,  1.19it/s]
# Inner Epoch Loop:  41% 578/1402 [08:50<11:24,  1.20it/s]
# Inner Epoch Loop:  41% 579/1402 [08:50<11:14,  1.22it/s]
# Inner Epoch Loop:  41% 580/1402 [08:51<11:14,  1.22it/s]
# Inner Epoch Loop:  41% 581/1402 [08:52<11:18,  1.21it/s]
# Inner Epoch Loop:  42% 582/1402 [08:53<11:31,  1.19it/s]
# ...

# %%
!%load_ext tensorboard
# Out:
# /bin/bash: line 0: fg: no job control

# %%
# %tensorboard --logdir ./output/cat2cartoon
# Out:
# UsageError: Line magic function `%tensorboard` not found.

# %%
! pip install oyaml
! export CUDA_VISIBLE_DEVICES=1
! python test.py --experiment_dir ./output/cat2cartoon
# Out:
# ...
# 2020-11-02 23:37:20.807762: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-02 23:37:22.184583: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-02 23:37:22.220810: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-02 23:37:22.221491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-11-02 23:37:22.221551: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...
